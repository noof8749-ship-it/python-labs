# %%
import numpy as np
a=np.array([[0.,0.,0.],
           [10.,10.,10.],
           [20.,20.,20.],
           [30.,30.,30.]])

b=np.array([0.,1.,2.])

c = a+b
mask= (c >= 22)

# %%
print("Sum:", np.sum(a))
print("Min:", np.min(a))
print("Max:", np.max(a))
b=np.array([0.,1.,2.])


print("Mean per column:", np.mean(a, axis=0))
print("Mean per row:", np.mean(a, axis=1))
print("Max per row:", np.max(a, axis=1))
# Out:
# Sum: 180.0
# Min: 0.0
# Max: 30.0
# Mean: 15.0
# Std: 11.180339887498949
# Var: 125.0
# Mean per column: [15. 15. 15.]
# Mean per row: [ 0. 10. 20. 30.]
# Max per row: [ 0. 10. 20. 30.]

# %%
a=np.array([[10.,20.,30.],
           [40.,50.,60.]])

b=np.array([1.,2.,3.])
print (np.argmax(a))
print (np.argmin(a))
# Out:
# 5
# 0
